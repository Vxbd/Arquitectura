# %%
import matplotlib.pyplot as plt
import csv

datos1 = [] #Creamos a lista para almacenar os datos

with open('proba1.csv', newline='') as File:  #Abrimos o arquivo e creamos o punteiro
    reader = csv.reader(File) #Creamos e inicalizamos o "lector" para archivo csv
    for row in reader: #Almacenamos a información na lista
        datos1.append(row)
        
datos2 = []
with open('proba15.csv', newline='') as File:  #Abrimos o arquivo e creamos o punteiro
    reader = csv.reader(File) #Creamos e inicalizamos o "lector" para archivo csv
    for row in reader: #Almacenamos a información na lista
        datos2.append(row)
        
#Adaptamos os datos para facer o plot
x = []
y = []

q = []
w = []
for i in range(len(datos1)):
    x.append(datos1[i][0])
    y.append(datos1[i][1])
for i in range(len(datos2)):
    q.append(datos2[i][0])
    w.append(datos2[i][1])
plt.plot(y ,x, 'rv-')
#plt.axis([0, max(x)],[0,max(y)])
plt.gcf().autofmt_xdate()
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

datos1 = [] #Creamos a lista para almacenar os datos
with open('proba1.csv', newline='') as File:  #Abrimos o arquivo e creamos o punteiro
    reader = csv.reader(File) #Creamos e inicalizamos o "lector" para archivo csv
    for row in reader: #Almacenamos a información na lista
        datos1.append(row)
        
datos3 = []
with open('proba3.csv', newline='') as File:  #Abrimos o arquivo e creamos o punteiro
    reader = csv.reader(File) #Creamos e inicalizamos o "lector" para archivo csv
    for row in reader: #Almacenamos a información na lista
        datos3.append(row)
        
datos15 = [] #Creamos a lista para almacenar os datos
with open('proba15.csv', newline='') as File:  #Abrimos o arquivo e creamos o punteiro
    reader = csv.reader(File) #Creamos e inicalizamos o "lector" para archivo csv
    for row in reader: #Almacenamos a información na lista
        datos1.append(row)
        
datos40 = []
with open('proba40.csv', newline='') as File:  #Abrimos o arquivo e creamos o punteiro
    reader = csv.reader(File) #Creamos e inicalizamos o "lector" para archivo csv
    for row in reader: #Almacenamos a información na lista
        datos40.append(row)
        
datos80 = []
with open('proba80.csv', newline='') as File:  #Abrimos o arquivo e creamos o punteiro
    reader = csv.reader(File) #Creamos e inicalizamos o "lector" para archivo csv
    for row in reader: #Almacenamos a información na lista
        datos80.append(row)
        
#Adaptamos os datos para facer o plot
x1 = []
y1 = []

x3 = []
y3 = []

x15 = []
y15 = []

x40 = []
y40 = []

x80 = []
y80 = []

for i in range(len(datos1)):
    x1.append(datos1[i][1])
    y1.append(datos1[i][0])

for i in range(len(datos3)):
    x3.append(datos1[i][1])
    y3.append(datos1[i][0])

for i in range(len(datos15)):
    x15.append(datos1[i][1])
    y15.append(datos1[i][0])

for i in range(len(datos40)):
    x40.append(datos1[i][1])
    y40.append(datos1[i][0])

for i in range(len(datos80)):
    x80.append(datos1[i][1])
    y80.append(datos1[i][0])
    
#plt.plot(x1 ,y1, 'rv-')
#plt.axis([0, max(x)],[0,max(y)])
#plt.gcf().autofmt_xdate()
#plt.show()

plt.plot(x1 ,y1, 'rv-', x3 ,y3, 'yv-', x15 ,y15, 'gv-' ,x40 ,y40, 'ro-', x80 ,y80, 'bv-')
#plt.axis([0, max(x)],[0,max(y)])
plt.gcf().autofmt_xdate()
plt.show()

# %%
datos1
# Out:
# [['16.8886718750', ' 256'],
#  ['23.9579427083', ' 768'],
#  ['23.9211791992', ' 2048'],
#  ['22.0178710937', ' 6144'],
#  ['18.3077630401', ' 24578'],
#  ['11.9837754632', ' 36867'],
#  ['9.0872602670', ' 98312'],
#  ['7.5556172918', ' 196625'],
#  ['7.3303596313', ' 393250'],
#  ['9.3812500000', ' 256'],
#  ['23.9748046875', ' 768'],
#  ['23.9142944336', ' 2048'],
#  ['23.8928222656', ' 6144'],
#  ['12.5792497355', ' 24578'],
#  ['10.0105948409', ' 36867'],
#  ['7.9618247934', ' 98312'],
#  ['7.3934633185', ' 196625'],
#  ['7.3812913541', ' 393250'],
#  ['9.4544921875', ' 256'],
#  ['23.9673177083', ' 768'],
#  ['23.9392944336', ' 2048'],
#  ['24.2518676758', ' 6144'],
#  ['16.0718966149', ' 24578'],
#  ['10.4708140071', ' 36867'],
#  ['7.1239979657', ' 98312'],
#  ['7.5188226319', ' 196625'],
#  ['7.4001622378', ' 393250'],
#  ['12.6839843750', ' 256'],
#  ['23.9388671875', ' 768'],
#  ['23.9691894531', ' 2048'],
#  ['23.8987182617', ' 6144'],
#  ['18.3329074782', ' 24578'],
# ...

# %%
Integer.ParseInt('1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-99b805aa763c> in <module>()
# ----> 1 Integer.ParseInt('1')
#
# NameError: name 'Integer' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-9f9472856892> in <module>()
#      14 # defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#      15 for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
# ---> 16     xs = randrange(n, 23, 32)
#      17     ys = randrange(n, 0, 100)
#      18     zs = randrange(n, zlow, zhigh)
#
# <ipython-input-32-9f9472856892> in randrange(n, vmin, vmax)
#       4     with each number distributed Uniform(vmin, vmax).
#       5     '''
# ----> 6     return (vmax - vmin)*np.random.rand(n) + vmin
#       7
#       8 fig = plt.figure()
#
# NameError: name 'np' is not defined

# %%
import latex.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-722d59bd7675> in <module>()
# ----> 1 import latex.py
#
# ModuleNotFoundError: No module named 'latex'

# %%
pip install pylatex
# Out:
#   File "<ipython-input-41-17941fe24e73>", line 1
#     pip install pylatex
#               ^
# SyntaxError: invalid syntax
